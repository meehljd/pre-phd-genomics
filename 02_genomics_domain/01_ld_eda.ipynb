# %%
import pandas as pd

# %%
path = "/home/ext_meehl_joshua_mayo_edu/pre-phd-genomics/02_genomics_domain/data/plink/tapestry/chr18_cds.fam"

# %%
df = pd.read_csv(path, sep="\t", header=None)
df.head()
# Out:
#    0           1  2  3  4  5
# 0  0  AAGWLAE326  0  0  0 -9
# 1  0  AAIWLAE717  0  0  0 -9
# 2  0  AAIZAAR717  0  0  0 -9
# 3  0  AAIZKAH036  0  0  0 -9
# 4  0  AAJWLAE907  0  0  0 -9

# %%
df[5].value_counts()
# Out:
# 5
# -9    97422
# Name: count, dtype: int64
