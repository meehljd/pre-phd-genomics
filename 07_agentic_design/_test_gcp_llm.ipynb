# %%
import vertexai
from vertexai.generative_models import GenerativeModel

# %%
# https://mcc.mayo.edu/products/aif-llm

vertexai.init(project="aif-usr-p-cbr-genai-1524", location="us-central1")
model = GenerativeModel("gemini-2.0-flash-001")
# Out:
# /home/m333442/miniconda3/lib/python3.13/site-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()

# %%
response = model.generate_content("Which came first, the chicken or the egg?")
print(response.text)
# Out:
# This is a classic philosophical question! Here's a breakdown of why the answer is generally considered to be **the egg**:
#
# *   **Evolutionary Perspective:** Chickens evolved from earlier bird-like species. There had to be an egg laid by a bird that was *almost* a chicken, with a genetic mutation inside that egg that made the bird that hatched from it the first "true" chicken. So, the egg containing the first chicken came before the chicken itself.
#
# *   **Definition of a Chicken Egg:** If we define a "chicken egg" as an egg laid by a chicken, then obviously the chicken had to exist first. However, the evolutionary argument addresses the origin of the chicken species itself.
#
# **In summary:**
#
# While the question is a bit of a word trick, the scientifically accepted answer, when considering the evolution of species, is that the egg came first.
