# %%
import vertexai
from vertexai.generative_models import GenerativeModel
# Out:
# /home/ext_meehl_joshua_mayo_edu/.conda/envs/pre-phd-genomics/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
# https://mcc.mayo.edu/products/aif-llm

vertexai.init(project="aif-usr-p-cbr-genai-1524", location="us-central1")
model = GenerativeModel("gemini-2.0-flash-001")

# %%
response = model.generate_content("What are the current top 3 genomic foundation models as of November 2025?")
print(response.text)
# Out:
# Okay, projecting to November 2025 and identifying the top 3 genomic foundation models is speculative, as this field is evolving rapidly. However, based on current trends (late 2023) and anticipating reasonable advancements in the next two years, I can give you a well-informed, hypothetical list and justification:
#
# **It's important to preface this with:**  The definition of "top" can vary.  I'm assuming "top" is based on a combination of:
#
# *   **Performance:** Accuracy on various genomic tasks (variant calling, disease prediction, drug response prediction, understanding regulatory elements, etc.)
# *   **Generalizability:** Ability to transfer learning across different species, data types, and tasks.
# *   **Accessibility/Usability:**  Availability of pre-trained models, ease of fine-tuning, and community support.
# *   **Scalability:** Ability to handle large genomic datasets.
# *   **Innovation:** Novel architectural approaches and capabilities beyond existing models.
#
# ...
